# %% [markdown]
# # Estimadores a través de datos

# %%
import sklearn 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.datasets import load_iris 
from scipy import stats
import seaborn as sns

# %matplotlib inline

# %%
from scipy.stats import norm

x1 = 3
mu1 = 4
mu2 = 7
sigma = 1

p_muestra = norm.pdf(x1, mu2, sigma)
p_muestra
# Out:
# 0.00013383022576488537

# %%
from scipy.stats import norm

x1 = 3
x2 = 10

mu1 = 4
mu2 = 7
sigma = 1

p_muestra = norm.pdf(x1, mu2, sigma)*norm.pdf(x2, mu2, sigma)
p_muestra
# Out:
# 5.931152735254122e-07

# %%
muestra_10 = norm.rvs(5, sigma, size=10)

# %%
data1 = norm.rvs(mu1, sigma, size=100000)
data2 = norm.rvs(mu2, sigma, size=100000)

# %%
ax = sns.distplot(data1, bins=50, color='blue', kde=False)

ax = sns.distplot(data2, bins=50, color='red', kde=False)
ax.set(xlabel='Distribución normal mu1 y mu2', ylabel='Frecuencia')
# Out:
# [Text(0.5, 0, 'Distribución normal mu1 y mu2'), Text(0, 0.5, 'Frecuencia')]

# %%
muestra_10

y = []

for _ in range(10):
    y.append(3000)

# %%
ax = sns.distplot(data1, bins=50, color='blue', kde=False)

ax = sns.distplot(data2, bins=50, color='red', kde=False)
ax.set(xlabel='Distribución normal mu1 y mu2', ylabel='Frecuencia')

ax.scatter(muestra_10, y, c='g')
